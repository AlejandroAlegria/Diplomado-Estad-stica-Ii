# %% [markdown]
# # RETO ENARM

# %% [markdown]
# ## PROBABILIDAD DE APROBAR MAYOR A 50%.

# %% [markdown]
# El reto consiste en calcular cuantas veces es necesario presentar el examen ENARM para tener una probabilidad de aprobarlo superior al 50%.

# %% [markdown]
# Primero insertamos un Power Point con el Árbol de Probabilidades para la toma de decisión

# %% [markdown]
# ![image.png](attachment:image.png)
